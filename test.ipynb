# %%
import torch
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("data/original_sequences/c40/crop_images/000/0001.png")
img2 = cv2.imread("data/original_sequences/c40/crop_images/000/0002.png")

img1 = img1[...,::-1]
img2 = img2[...,::-1]

# %%
plt.subplot(1,2,1)
plt.imshow(img1)
plt.subplot(1,2,2)
plt.imshow(img2)

# %%
img3 = img2 - img1
plt.imshow(img3)

# %%
img11 = cv2.imread("data/manipulated_sequences/Deepfakes/c40/crop_images/000_003/0001.png")
img22 = cv2.imread("data/manipulated_sequences/Deepfakes/c40/crop_images/000_003/0002.png")

img11 = img11[...,::-1]
img22 = img22[...,::-1]

# %%
plt.subplot(1,2,1)
plt.imshow(img11)
plt.subplot(1,2,2)
plt.imshow(img22)

# %%
img33 = img22 - img11
plt.imshow(img33)

# %%
logits_rgb = torch.rand(32, 2)
logits_diff = torch.rand(32, 2)

# %%
print(logits_rgb[0])
print(logits_diff[0])
# Out:
# tensor([0.8396, 0.2874])
# tensor([0.5863, 0.3084])

# %%
logits_avg = (logits_rgb + logits_diff)/2

# %%
logits_avg[0]
# Out:
# tensor([0.7130, 0.2979])
